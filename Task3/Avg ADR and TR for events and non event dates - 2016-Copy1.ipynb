# %%
import pandas as pd
import numpy as np

data = pd.read_csv('/Users/Amulya/Desktop/EventsDataAnalysis/Task3/Results/RequiredDataSet.csv',header=None, names=['booking_date','channel','property_id','room_name','room_id','check_in','check_out','room_rate','booking_status'])
data.head()
# Out:
#                 booking_date channel property_id                 room_name  \
# 0  2013-06-30T16:35:42+05:30  DIRECT          CH             Superior Room
# 1  2013-02-08T17:06:44+05:30  DIRECT          BB  Standard Sea Facing Room
# 2  2013-02-08T17:06:44+05:30  DIRECT          BB  Standard Sea Facing Room
# 3  2013-02-08T17:06:44+05:30  DIRECT          BB  Standard Sea Facing Room
# 4  2013-02-08T17:06:44+05:30  DIRECT          BB  Standard Sea Facing Room
#
#   room_id    check_in   check_out  room_rate booking_status
# 0      ST  2013-07-08  2014-04-15        0.0      COMPLETED
# 1      1F  2014-03-01  2014-04-30        0.0      CANCELLED
# 2      1F  2014-03-01  2014-04-30        0.0      CANCELLED
# 3      1F  2014-03-01  2014-04-30        0.0      CANCELLED
# 4      1F  2014-03-01  2014-04-30        0.0      CANCELLED

# %%
Results = pd.read_excel('/Users/Amulya/Desktop/EventsDataAnalysis/Task3/Results/DataSetWithStayDate.xlsx')

# %%
Results.head()
# Out:
#                 Booking_date Booking_status Channel    Check_in   Check_out  \
# 0  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 1  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 2  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 3  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 4  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
#
#   Property_id Room_details      Room_name  Old_Room_rate  Room_rate  \
# 0          CH           ST  Superior Room            0.0        0.0
# 1          CH           ST  Superior Room            0.0        0.0
# 2          CH           ST  Superior Room            0.0        0.0
# 3          CH           ST  Superior Room            0.0        0.0
# 4          CH           ST  Superior Room            0.0        0.0
#
#     Stay_date
# 0  2013-07-08
# 1  2013-07-09
# 2  2013-07-10
# 3  2013-07-11
# 4  2013-07-12

# %%
del Results['Old_Room_rate']
Results.head()
# Out:
#                 Booking_date Booking_status Channel    Check_in   Check_out  \
# 0  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 1  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 2  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 3  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
# 4  2013-06-30T16:35:42+05:30      COMPLETED  DIRECT  2013-07-08  2014-04-15
#
#   Property_id Room_details      Room_name  Room_rate   Stay_date
# 0          CH           ST  Superior Room        0.0  2013-07-08
# 1          CH           ST  Superior Room        0.0  2013-07-09
# 2          CH           ST  Superior Room        0.0  2013-07-10
# 3          CH           ST  Superior Room        0.0  2013-07-11
# 4          CH           ST  Superior Room        0.0  2013-07-12

# %%
scrapyData = pd.read_csv('/Users/Amulya/Desktop/EventsDataAnalysis/Task3/Results/eventData2016.csv',header=None, names=['Day','Stay_date','Event','HolidayIn'])

# %%
scrapeResult = scrapyData.dropna()

# %%
scrapeResult.head()
# Out:
#         Day   Stay_date                          Event  \
# 0    Friday  January 01                  New Years Day
# 1  Saturday  January 02                Mannam Jayanthi
# 2   Tuesday  January 12  Birthday of Swami Vivekananda
# 3  Thursday  January 14                          Bhogi
# 4  Thursday  January 14                         Pongal
#
#                                            HolidayIn
# 0  Arunachal pradesh, Manipur, Meghalaya, Miizora...
# 1                                        Kerala Only
# 2                                  West Bengal only.
# 3                                          Telangana
# 4  Also known as Makar Sankranti, Lohri, Bihu, Ha...

# %%
scrapeResult['Stay_date'] =   '2016-' + scrapeResult['Stay_date']
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
scrapeResult.head()
# Out:
#         Day        Stay_date                          Event  \
# 0    Friday  2016-January 01                  New Years Day
# 1  Saturday  2016-January 02                Mannam Jayanthi
# 2   Tuesday  2016-January 12  Birthday of Swami Vivekananda
# 3  Thursday  2016-January 14                          Bhogi
# 4  Thursday  2016-January 14                         Pongal
#
#                                            HolidayIn
# 0  Arunachal pradesh, Manipur, Meghalaya, Miizora...
# 1                                        Kerala Only
# 2                                  West Bengal only.
# 3                                          Telangana
# 4  Also known as Makar Sankranti, Lohri, Bihu, Ha...

# %%
scrapeResult['Stay_date'] = pd.to_datetime(scrapeResult.Stay_date)
#pd.to_datetime('02/Jan/2015:08:07:32', format='%d/%b/%Y:%H:%M:%S')
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
scrapeResult.head()
# Out:
#         Day  Stay_date                          Event  \
# 0    Friday 2016-01-01                  New Years Day
# 1  Saturday 2016-01-02                Mannam Jayanthi
# 2   Tuesday 2016-01-12  Birthday of Swami Vivekananda
# 3  Thursday 2016-01-14                          Bhogi
# 4  Thursday 2016-01-14                         Pongal
#
#                                            HolidayIn
# 0  Arunachal pradesh, Manipur, Meghalaya, Miizora...
# 1                                        Kerala Only
# 2                                  West Bengal only.
# 3                                          Telangana
# 4  Also known as Makar Sankranti, Lohri, Bihu, Ha...

# %%
del scrapeResult['HolidayIn']

# %%
scrapeResult.head()
# Out:
#         Day  Stay_date                          Event
# 0    Friday 2016-01-01                  New Years Day
# 1  Saturday 2016-01-02                Mannam Jayanthi
# 2   Tuesday 2016-01-12  Birthday of Swami Vivekananda
# 3  Thursday 2016-01-14                          Bhogi
# 4  Thursday 2016-01-14                         Pongal

# %%
newResults = Results.filter(['Property_id','Stay_date','Booking_status','Room_name','Room_details','Room_rate','Channel'], axis=1)
newResults.head()
# Out:
#   Property_id   Stay_date Booking_status      Room_name Room_details  \
# 0          CH  2013-07-08      COMPLETED  Superior Room           ST
# 1          CH  2013-07-09      COMPLETED  Superior Room           ST
# 2          CH  2013-07-10      COMPLETED  Superior Room           ST
# 3          CH  2013-07-11      COMPLETED  Superior Room           ST
# 4          CH  2013-07-12      COMPLETED  Superior Room           ST
#
#    Room_rate Channel
# 0        0.0  DIRECT
# 1        0.0  DIRECT
# 2        0.0  DIRECT
# 3        0.0  DIRECT
# 4        0.0  DIRECT

# %%
newResults = newResults[(newResults.Booking_status == 'COMPLETED') | (newResults.Booking_status == 'CONFIRMED')]
newResults.head()
# Out:
#   Property_id   Stay_date Booking_status      Room_name Room_details  \
# 0          CH  2013-07-08      COMPLETED  Superior Room           ST
# 1          CH  2013-07-09      COMPLETED  Superior Room           ST
# 2          CH  2013-07-10      COMPLETED  Superior Room           ST
# 3          CH  2013-07-11      COMPLETED  Superior Room           ST
# 4          CH  2013-07-12      COMPLETED  Superior Room           ST
#
#    Room_rate Channel
# 0        0.0  DIRECT
# 1        0.0  DIRECT
# 2        0.0  DIRECT
# 3        0.0  DIRECT
# 4        0.0  DIRECT

# %%
newResults = newResults[(newResults.Stay_date >= '2016-01-01') & (newResults.Stay_date <= '2016-12-31')]
newResults.head()
# Out:
#      Property_id   Stay_date Booking_status         Room_name Room_details  \
# 7401          CL  2016-07-02      COMPLETED  Heritage Mansion           HM
# 7402          CL  2016-07-03      COMPLETED  Heritage Mansion           HM
# 7403          CL  2016-07-04      COMPLETED  Heritage Mansion           HM
# 7404          CL  2016-07-05      COMPLETED  Heritage Mansion           HM
# 7405          CL  2016-07-06      COMPLETED  Heritage Mansion           HM
#
#       Room_rate        Channel
# 7401        0.0  TRAVEL AGENTS
# 7402        0.0  TRAVEL AGENTS
# 7403        0.0  TRAVEL AGENTS
# 7404        0.0  TRAVEL AGENTS
# 7405        0.0  TRAVEL AGENTS

# %%
newResults['Stay_date'] = pd.to_datetime(newResults.Stay_date)

# %%
newResults.head()
# Out:
#      Property_id  Stay_date Booking_status         Room_name Room_details  \
# 7401          CL 2016-07-02      COMPLETED  Heritage Mansion           HM
# 7402          CL 2016-07-03      COMPLETED  Heritage Mansion           HM
# 7403          CL 2016-07-04      COMPLETED  Heritage Mansion           HM
# 7404          CL 2016-07-05      COMPLETED  Heritage Mansion           HM
# 7405          CL 2016-07-06      COMPLETED  Heritage Mansion           HM
#
#       Room_rate        Channel
# 7401        0.0  TRAVEL AGENTS
# 7402        0.0  TRAVEL AGENTS
# 7403        0.0  TRAVEL AGENTS
# 7404        0.0  TRAVEL AGENTS
# 7405        0.0  TRAVEL AGENTS

# %%
del newResults['Room_details']

# %%
scrapeResult.head()
# Out:
#         Day  Stay_date                          Event
# 0    Friday 2016-01-01                  New Years Day
# 1  Saturday 2016-01-02                Mannam Jayanthi
# 2   Tuesday 2016-01-12  Birthday of Swami Vivekananda
# 3  Thursday 2016-01-14                          Bhogi
# 4  Thursday 2016-01-14                         Pongal

# %%
del scrapeResult['Day']

# %%
scrapeResult.head()
# Out:
#    Stay_date                          Event
# 0 2016-01-01                  New Years Day
# 1 2016-01-02                Mannam Jayanthi
# 2 2016-01-12  Birthday of Swami Vivekananda
# 3 2016-01-14                          Bhogi
# 4 2016-01-14                         Pongal

# %%
res = pd.merge(left=newResults, left_on='Stay_date',right=scrapeResult, right_on='Stay_date', how='left')

#res = pd.merge(newResults, scrapeResult, on='Stay_date', how='left')

# %%
res = res.sort_values(by = 'Stay_date', ascending=True)
res
# Out:
#       Property_id  Stay_date Booking_status                 Room_name  \
# 1714           EB 2016-01-01      COMPLETED             Standard Room
# 1328           KK 2016-01-01      COMPLETED    Vengunad Suite (018 L)
# 2246           CH 2016-01-01      COMPLETED             Superior Room
# 1983           CH 2016-01-01      COMPLETED             Superior Room
# 1982           CH 2016-01-01      COMPLETED             Superior Room
# 1981           CL 2016-01-01      COMPLETED          Heritage Mansion
# 1336           KR 2016-01-01      COMPLETED        Rasayana Gf 502  T
# 2248           CH 2016-01-01      COMPLETED             Superior Room
# 1980           CL 2016-01-01      COMPLETED          Heritage Mansion
# 1979           CL 2016-01-01      COMPLETED         Heritage Bungalow
# 2250           SV 2016-01-01      COMPLETED            Standard Villa
# 1327           SS 2016-01-01      COMPLETED              Konkan Villa
# 1347           KR 2016-01-01      COMPLETED         Rasayana Gf 501 T
# 2251           CL 2016-01-01      COMPLETED         Heritage Bungalow
# 2253           CH 2016-01-01      COMPLETED             Superior Room
# 1972           CL 2016-01-01      COMPLETED          Heritage Mansion
# 1971           CL 2016-01-01      COMPLETED          Heritage Mansion
# 1359           CH 2016-01-01      COMPLETED             Superior Room
# 2254           SV 2016-01-01      COMPLETED            Standard Villa
# 2256           MB 2016-01-01      COMPLETED              Garden Villa
# 2257           MB 2016-01-01      COMPLETED              Garden Villa
# 1965           CL 2016-01-01      COMPLETED          Heritage Mansion
# 1368           CL 2016-01-01      COMPLETED         Heritage Bungalow
# 2801           SV 2016-01-01      COMPLETED            Standard Villa
# 2259           MB 2016-01-01      COMPLETED              Garden Villa
# 1984           BB 2016-01-01      COMPLETED  Standard Sea Facing Room
# 1988           BB 2016-01-01      COMPLETED  Standard Sea Facing Room
# 2234           CH 2016-01-01      COMPLETED             Superior Room
# 1283           EB 2016-01-01      COMPLETED             Standard Room
# 2012           CL 2016-01-01      COMPLETED         Heritage Bungalow
# ...           ...        ...            ...                       ...
# 96456          CL 2016-12-31      CONFIRMED         Heritage Bungalow
# 96424          CH 2016-12-31      CONFIRMED             Superior Room
# 96426          BB 2016-12-31      CONFIRMED  Standard Sea Facing Room
# 96454          CL 2016-12-31      CONFIRMED         Heritage Bungalow
# 96453          CL 2016-12-31      CONFIRMED         Heritage Bungalow
# 96452          MB 2016-12-31      CONFIRMED              Garden Villa
# 96451          VM 2016-12-31      CONFIRMED             Standard Room
# 95632          CL 2016-12-31      CONFIRMED         Deluxe Pool Villa
# 96449          CL 2016-12-31      CONFIRMED         Heritage Bungalow
# 95639          EB 2016-12-31      CONFIRMED             Standard Room
# 96444          CL 2016-12-31      CONFIRMED          Heritage Mansion
# 96453   16500.00  TRAVEL AGENTS            NaN
# 96452   15355.00  TRAVEL AGENTS            NaN
# 96451   14175.00  TRAVEL AGENTS            NaN
# 95632   32000.00  TRAVEL AGENTS            NaN
# 96449   16500.00  TRAVEL AGENTS            NaN
# 95639   13575.00  TRAVEL AGENTS            NaN
# 96444   18560.00  TRAVEL AGENTS            NaN
# 96443   18560.00  TRAVEL AGENTS            NaN
# 96442   20182.50  TRAVEL AGENTS            NaN
# 96441   20100.00  TRAVEL AGENTS            NaN
# 96440   16500.00  TRAVEL AGENTS            NaN
# 96439   16500.00  TRAVEL AGENTS            NaN
# 96438    8000.00         DIRECT            NaN
# 96437    8000.00         DIRECT            NaN
# 96436    8000.00         DIRECT            NaN
# 96435    8000.00         DIRECT            NaN
# 96434    8000.00         DIRECT            NaN
# 96433    8000.00         DIRECT            NaN
# 96432    8000.00         DIRECT            NaN
# 96431    8000.00         DIRECT            NaN
# 96430    8000.00         DIRECT            NaN
# 96429    8000.00         DIRECT            NaN
# 96428   31125.00  TRAVEL AGENTS            NaN
# 96427   31125.00  TRAVEL AGENTS            NaN
# 96425   22425.00  TRAVEL AGENTS            NaN
# 96756    5500.00         DIRECT            NaN
#
# [96757 rows x 7 columns]

# %%
res1 = res.drop_duplicates()

# %%
res1.head()
# Out:
#      Property_id  Stay_date Booking_status               Room_name  Room_rate  \
# 1714          EB 2016-01-01      COMPLETED           Standard Room     6000.0
# 1328          KK 2016-01-01      COMPLETED  Vengunad Suite (018 L)    55650.0
# 2246          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 1983          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 1981          CL 2016-01-01      COMPLETED        Heritage Mansion    18560.0
#
#             Channel          Event
# 1714  TRAVEL AGENTS  New Years Day
# 1328         DIRECT  New Years Day
# 2246  TRAVEL AGENTS  New Years Day
# 1983            OTA  New Years Day
# 1981  TRAVEL AGENTS  New Years Day

# %%
res1 = res1.reset_index()

# %%
res1.head()
# Out:
#    index Property_id  Stay_date Booking_status               Room_name  \
# 0   1714          EB 2016-01-01      COMPLETED           Standard Room
# 1   1328          KK 2016-01-01      COMPLETED  Vengunad Suite (018 L)
# 2   2246          CH 2016-01-01      COMPLETED           Superior Room
# 3   1983          CH 2016-01-01      COMPLETED           Superior Room
# 4   1981          CL 2016-01-01      COMPLETED        Heritage Mansion
#
#    Room_rate        Channel          Event
# 0     6000.0  TRAVEL AGENTS  New Years Day
# 1    55650.0         DIRECT  New Years Day
# 2     3000.0  TRAVEL AGENTS  New Years Day
# 3     3000.0            OTA  New Years Day
# 4    18560.0  TRAVEL AGENTS  New Years Day

# %%
del res1['index']

# %%
res1.head()
# Out:
#   Property_id  Stay_date Booking_status               Room_name  Room_rate  \
# 0          EB 2016-01-01      COMPLETED           Standard Room     6000.0
# 1          KK 2016-01-01      COMPLETED  Vengunad Suite (018 L)    55650.0
# 2          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 3          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 4          CL 2016-01-01      COMPLETED        Heritage Mansion    18560.0
#
#          Channel          Event
# 0  TRAVEL AGENTS  New Years Day
# 1         DIRECT  New Years Day
# 2  TRAVEL AGENTS  New Years Day
# 3            OTA  New Years Day
# 4  TRAVEL AGENTS  New Years Day

# %%
res1 = res1.fillna('-')

# %%
events = res1[(res1.Event != '-') ]
events.head()
# Out:
#   Property_id  Stay_date Booking_status               Room_name  Room_rate  \
# 0          EB 2016-01-01      COMPLETED           Standard Room     6000.0
# 1          KK 2016-01-01      COMPLETED  Vengunad Suite (018 L)    55650.0
# 2          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 3          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 4          CL 2016-01-01      COMPLETED        Heritage Mansion    18560.0
#
#          Channel          Event
# 0  TRAVEL AGENTS  New Years Day
# 1         DIRECT  New Years Day
# 2  TRAVEL AGENTS  New Years Day
# 3            OTA  New Years Day
# 4  TRAVEL AGENTS  New Years Day

# %%
events['totalRevenue'] = events.groupby(['Property_id','Stay_date'])['Room_rate'].transform('mean')
events
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#       Property_id  Stay_date Booking_status                   Room_name  \
# 0              EB 2016-01-01      COMPLETED               Standard Room
# 1              KK 2016-01-01      COMPLETED      Vengunad Suite (018 L)
# 2              CH 2016-01-01      COMPLETED               Superior Room
# 3              CH 2016-01-01      COMPLETED               Superior Room
# 4              CL 2016-01-01      COMPLETED            Heritage Mansion
# 5              KR 2016-01-01      COMPLETED          Rasayana Gf 502  T
# 6              CL 2016-01-01      COMPLETED           Heritage Bungalow
# 7              SV 2016-01-01      COMPLETED              Standard Villa
# 8              SS 2016-01-01      COMPLETED                Konkan Villa
# 9              KR 2016-01-01      COMPLETED           Rasayana Gf 501 T
# 10             CL 2016-01-01      COMPLETED           Heritage Bungalow
# 11             CH 2016-01-01      COMPLETED               Superior Room
# 12             CH 2016-01-01      COMPLETED               Superior Room
# 13             SV 2016-01-01      COMPLETED              Standard Villa
# 14             MB 2016-01-01      COMPLETED                Garden Villa
# 15             MB 2016-01-01      COMPLETED                Garden Villa
# 16             CL 2016-01-01      COMPLETED            Heritage Mansion
# 17             CL 2016-01-01      COMPLETED           Heritage Bungalow
# 18             SV 2016-01-01      COMPLETED              Standard Villa
# 19             BB 2016-01-01      COMPLETED    Standard Sea Facing Room
# 20             BB 2016-01-01      COMPLETED    Standard Sea Facing Room
# 21             EB 2016-01-01      COMPLETED               Standard Room
# 22             CL 2016-01-01      COMPLETED           Heritage Bungalow
# 23             KK 2016-01-01      COMPLETED   Kovilakom Suite (019 L P)
# 24             SV 2016-01-01      COMPLETED              Standard Villa
# 25             CL 2016-01-01      COMPLETED            Heritage Mansion
# 26             CL 2016-01-01      COMPLETED           Heritage Bungalow
# 27             KR 2016-01-01      COMPLETED          Rasayana Suite 105
# 28             SV 2016-01-01      COMPLETED              Standard Villa
# 49833   13800.00         DIRECT  Shaheed Udham Singh's Birthday  13754.000000
# 49834   18837.00         DIRECT  Shaheed Udham Singh's Birthday  22800.166667
# 49835   19614.28         DIRECT  Shaheed Udham Singh's Birthday  17377.910455
# 49836   16900.00  TRAVEL AGENTS  Shaheed Udham Singh's Birthday  14505.625000
# 49837   14000.00         DIRECT  Shaheed Udham Singh's Birthday  17377.910455
# 49838       0.00     CORPORATES  Shaheed Udham Singh's Birthday    246.732500
#
# [17375 rows x 8 columns]

# %%
# events_tr = events["totalRevenue"].mean()
# events_tr

# %%
events['room_count'] = events.groupby(['Property_id','Stay_date'])['Room_rate'].transform('count')
events.head()
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#   Property_id  Stay_date Booking_status               Room_name  Room_rate  \
# 0          EB 2016-01-01      COMPLETED           Standard Room     6000.0
# 1          KK 2016-01-01      COMPLETED  Vengunad Suite (018 L)    55650.0
# 2          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 3          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 4          CL 2016-01-01      COMPLETED        Heritage Mansion    18560.0
#
#          Channel          Event  totalRevenue  room_count
# 0  TRAVEL AGENTS  New Years Day  10300.000000           6
# 1         DIRECT  New Years Day  12690.850000          11
# 2  TRAVEL AGENTS  New Years Day   4153.333333          15
# 3            OTA  New Years Day   4153.333333          15
# 4  TRAVEL AGENTS  New Years Day  20163.288333          24

# %%
events['ADR'] = events.apply(lambda events: (events['totalRevenue'] / events['room_count'] ) , axis=1)
events.head()
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#   Property_id  Stay_date Booking_status               Room_name  Room_rate  \
# 0          EB 2016-01-01      COMPLETED           Standard Room     6000.0
# 1          KK 2016-01-01      COMPLETED  Vengunad Suite (018 L)    55650.0
# 2          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 3          CH 2016-01-01      COMPLETED           Superior Room     3000.0
# 4          CL 2016-01-01      COMPLETED        Heritage Mansion    18560.0
#
#          Channel          Event  totalRevenue  room_count          ADR
# 0  TRAVEL AGENTS  New Years Day  10300.000000           6  1716.666667
# 1         DIRECT  New Years Day  12690.850000          11  1153.713636
# 2  TRAVEL AGENTS  New Years Day   4153.333333          15   276.888889
# 3            OTA  New Years Day   4153.333333          15   276.888889
# 4  TRAVEL AGENTS  New Years Day  20163.288333          24   840.137014

# %%
# events_adr = events["ADR"].unique().mean()
# events_adr

# %%
nonevents = res1[(res1.Event == '-') ]
nonevents.head()
# Out:
#     Property_id  Stay_date Booking_status          Room_name  Room_rate  \
# 321          SS 2016-01-03      COMPLETED       Konkan Villa   19123.07
# 322          KR 2016-01-03      COMPLETED  Rasayana Gf 701 T       0.00
# 323          MB 2016-01-03      COMPLETED  Deluxe Pool Villa   20500.00
# 324          MB 2016-01-03      COMPLETED       Garden Villa   17230.00
# 325          CH 2016-01-03      COMPLETED      Superior Room    4000.00
#
#            Channel Event
# 321  TRAVEL AGENTS     -
# 322         DIRECT     -
# 323         DIRECT     -
# 324         DIRECT     -
# 325     CORPORATES     -

# %%
nonevents['totalRevenue'] = nonevents.groupby(['Property_id','Stay_date'])['Room_rate'].transform('mean')
nonevents.head()
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#     Property_id  Stay_date Booking_status          Room_name  Room_rate  \
# 321          SS 2016-01-03      COMPLETED       Konkan Villa   19123.07
# 322          KR 2016-01-03      COMPLETED  Rasayana Gf 701 T       0.00
# 323          MB 2016-01-03      COMPLETED  Deluxe Pool Villa   20500.00
# 324          MB 2016-01-03      COMPLETED       Garden Villa   17230.00
# 325          CH 2016-01-03      COMPLETED      Superior Room    4000.00
#
#            Channel Event  totalRevenue
# 321  TRAVEL AGENTS     -  12546.588947
# 322         DIRECT     -  10265.978235
# 323         DIRECT     -  19205.868077
# 324         DIRECT     -  19205.868077
# 325     CORPORATES     -   4478.571429

# %%
# nonevents_tr = nonevents["totalRevenue"].unique().mean()
# nonevents_tr

# %%
nonevents['room_count'] = nonevents.groupby(['Property_id','Stay_date'])['Room_rate'].transform('count')
nonevents.head()
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#     Property_id  Stay_date Booking_status          Room_name  Room_rate  \
# 321          SS 2016-01-03      COMPLETED       Konkan Villa   19123.07
# 322          KR 2016-01-03      COMPLETED  Rasayana Gf 701 T       0.00
# 323          MB 2016-01-03      COMPLETED  Deluxe Pool Villa   20500.00
# 324          MB 2016-01-03      COMPLETED       Garden Villa   17230.00
# 325          CH 2016-01-03      COMPLETED      Superior Room    4000.00
#
#            Channel Event  totalRevenue  room_count
# 321  TRAVEL AGENTS     -  12546.588947          19
# 322         DIRECT     -  10265.978235          17
# 323         DIRECT     -  19205.868077          26
# 324         DIRECT     -  19205.868077          26
# 325     CORPORATES     -   4478.571429          14

# %%
nonevents['ADR'] = nonevents.apply(lambda nonevents: (nonevents['totalRevenue'] / nonevents['room_count'] ) , axis=1)
nonevents.head()
# Out:
# C:\Users\Amulya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#     Property_id  Stay_date Booking_status          Room_name  Room_rate  \
# 321          SS 2016-01-03      COMPLETED       Konkan Villa   19123.07
# 322          KR 2016-01-03      COMPLETED  Rasayana Gf 701 T       0.00
# 323          MB 2016-01-03      COMPLETED  Deluxe Pool Villa   20500.00
# 324          MB 2016-01-03      COMPLETED       Garden Villa   17230.00
# 325          CH 2016-01-03      COMPLETED      Superior Room    4000.00
#
#            Channel Event  totalRevenue  room_count         ADR
# 321  TRAVEL AGENTS     -  12546.588947          19  660.346787
# 322         DIRECT     -  10265.978235          17  603.881073
# 323         DIRECT     -  19205.868077          26  738.687234
# 324         DIRECT     -  19205.868077          26  738.687234
# 325     CORPORATES     -   4478.571429          14  319.897959

# %%
# nonevents_adr = nonevents["ADR"].unique().mean()
# nonevents_adr

# %%
property_id_BB16 = events[(events.Property_id == 'BB')]
property_id_BB16.to_excel('Results/BB16' +'.xlsx')

# %%
property_id_BBB16 = nonevents[(nonevents.Property_id == 'BB')]
property_id_BBB16.to_excel('Results/BBB16' +'.xlsx')
